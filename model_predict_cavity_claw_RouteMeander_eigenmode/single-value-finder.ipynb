# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("cavity_claw-RouteMeander-eigenmode.json")

# %%
def flatten(d, parent_key="", out=None):
    if out is None:
        out = {}

    for k, v in d.items():
        key = f"{parent_key}.{k}" if parent_key else k
        if isinstance(v, dict):
            flatten(v, key, out)
        else:
            out[key] = v
    return out

# %%
# in the coupler-NCap-cap_matrix there are different size design dictionaries for some reason
total_dict = {}
for newkey in flatten(df.design.iloc[0]):
    total_dict[newkey] = []


for i in df.design:
    this_dict = flatten(i)
    for k in this_dict:
        try:
            total_dict[k] += [this_dict[k]]
        except:
            total_dict[k] = [this_dict[k]]

# %%
multi_valued_params = []
single_valued_params = []

for j in total_dict:
    uniques = np.unique(total_dict[j])
    print("Parameter {}".format(j))
    print("Number of unique values:",len(uniques))
    print("Possible unique value(s):",uniques)
    print()

    if len(uniques) > 2:
        multi_valued_params.append(j)
    else:
        single_valued_params.append(j)
# Out:
# Parameter design_options.claw_opts.connection_pads.readout.connector_location
# Number of unique values: 1
# Possible unique value(s): ['90']
#
# Parameter design_options.claw_opts.connection_pads.readout.connector_type
# Number of unique values: 1
# Possible unique value(s): ['0']
#
# Parameter design_options.claw_opts.connection_pads.readout.claw_length
# Number of unique values: 167
# Possible unique value(s): ['100um' '102.5um' '105um' '107.5um' '110um' '112.5um' '115um' '120um'
#  '122.5um' '125um' '127.5um' '130um' '132.5um' '135um' '137.5um' '140um'
#  '142.5um' '145um' '147.5um' '150um' '152.5um' '155um' '157.5um' '160um'
#  '162.5um' '165um' '170um' '172.5um' '175um' '177.5um' '180um' '182.5um'
#  '185um' '187.5um' '190um' '192.5um' '195um' '197.5um' '200um' '202.5um'
#  '205um' '207.5um' '210um' '212.5um' '215um' '217.5um' '220um' '222.5um'
#  '225um' '227.5um' '230um' '232.5um' '235um' '237.5um' '240um' '242.5um'
#  '245um' '247.5um' '250um' '252.5um' '255um' '257.5um' '260um' '262.5um'
#  '265um' '267.5um' '270um' '272.5um' '275um' '277.5um' '280um' '282.5um'
#  '285um' '287.5um' '290um' '292.5um' '295um' '297.5um' '300um' '302.5um'
#  '305um' '307.5um' '310um' '312.5um' '315um' '317.5um' '320um' '322.5um'
#  '325um' '327.5um' '330um' '332.5um' '335um' '337.5um' '340um' '342.5um'
#  '345um' '347.5um' '350um' '352.5um' '355um' '357.5um' '360um' '362.5um'
#  '365um' '367.5um' '370um' '372.5um' '375um' '377.5um' '380um' '382.5um'
#  '385um' '387.5um' '390um' '392.5um' '395um' '397.5um' '400um' '402.5um'
#  '405um' '407.5um' '410um' '412.5um' '415um' '417.5um' '420um' '422.5um'
#  '425um' '427.5um' '430um' '432.5um' '435um' '437.5um' '440um' '442.5um'
#  '445um' '447.5um' '450um' '452.5um' '455um' '457.5um' '460um' '470um'
#  '477.5um' '480um' '490um' '500um' '510um' '520um' '527.5um' '530um'
#  '540um' '550um' '577.5um' '70um' '72.5um' '75um' '77.5um' '80um' '82.5um'
#  '85um' '87.5um' '90um' '92.5um' '95um' '97.5um']
#
# Parameter design_options.claw_opts.connection_pads.readout.ground_spacing
# Number of unique values: 2
# Possible unique value(s): ['10um' '4.1um']
#
# Parameter design_options.claw_opts.connection_pads.readout.claw_gap
# Number of unique values: 1
# Possible unique value(s): ['5.1um']
#
# Parameter design_options.claw_opts.connection_pads.readout.claw_width
# Number of unique values: 1
# Possible unique value(s): ['15um']
#
# Parameter design_options.claw_opts.connection_pads.readout.claw_cpw_width
# Number of unique values: 1
# Possible unique value(s): ['11.7um']
#
# Parameter design_options.claw_opts.connection_pads.readout.claw_cpw_length
# Number of unique values: 1
# Possible unique value(s): ['0um']
#
# Parameter design_options.claw_opts.orientation
# Number of unique values: 1
# Possible unique value(s): ['-90']
#
# Parameter design_options.claw_opts.pos_x
# Number of unique values: 2
# Possible unique value(s): ['-1000um' '-1500um']
#
# Parameter design_options.claw_opts.cross_length
# Number of unique values: 2
# Possible unique value(s): ['0um' '240um']
#
# Parameter design_options.claw_opts.cross_width
# Number of unique values: 2
# Possible unique value(s): ['0um' '30um']
#
# Parameter design_options.claw_opts.cross_gap
# Number of unique values: 2
# Possible unique value(s): ['0um' '30um']
#
# Parameter design_options.cpw_opts.fillet
# Number of unique values: 1
# Possible unique value(s): ['49.9um']
#
# Parameter design_options.cpw_opts.total_length
# Number of unique values: 21
# Possible unique value(s): ['1700um' '2200um' '2700um' '3000um' '3150um' '3200um' '3275um' '3400um'
#  '3700um' '3900um' '4200um' '4600um' '4700um' '5200um' '5700um' '6200um'
#  '6700um' '7200um' '7700um' '8200um' '8700um']
#
# Parameter design_options.cpw_opts.trace_width
# Number of unique values: 1
# Possible unique value(s): ['11.7um']
#
# Parameter design_options.cpw_opts.trace_gap
# Number of unique values: 1
# Possible unique value(s): ['5.1um']
#
# Parameter design_options.cpw_opts.lead.start_straight
# Number of unique values: 2
# Possible unique value(s): ['100um' '50um']
#
# Parameter design_options.cpw_opts.pin_inputs.start_pin.component
# Number of unique values: 1
# Possible unique value(s): ['cplr']
#
# Parameter design_options.cpw_opts.pin_inputs.start_pin.pin
# Number of unique values: 1
# Possible unique value(s): ['second_end']
#
# Parameter design_options.cpw_opts.pin_inputs.end_pin.component
# Number of unique values: 1
# Possible unique value(s): ['claw']
#
# Parameter design_options.cpw_opts.pin_inputs.end_pin.pin
# Number of unique values: 1
# Possible unique value(s): ['readout']
#
# Parameter design_options.cpw_opts.meander.spacing
# Number of unique values: 1
# Possible unique value(s): ['100um']
#
# Parameter design_options.cpw_opts.meander.asymmetry
# Number of unique values: 11
# Possible unique value(s): ['-100.0um' '-115.0um' '-175.0um' '-200.0um' '-250.0um' '-50.0um' '0.0um'
#  '116.66666666666667um' '133.33333333333334um' '66.66666666666667um'
#  '76.66666666666667um']
#
# Parameter design_options.cplr_opts.prime_width
# Number of unique values: 1
# Possible unique value(s): ['11.7um']
#
# Parameter design_options.cplr_opts.prime_gap
# Number of unique values: 1
# Possible unique value(s): ['5.1um']
#
# Parameter design_options.cplr_opts.second_width
# Number of unique values: 1
# Possible unique value(s): ['11.7um']
#
# Parameter design_options.cplr_opts.second_gap
# Number of unique values: 1
# Possible unique value(s): ['5.1um']
#
# Parameter design_options.cplr_opts.coupling_space
# Number of unique values: 1
# Possible unique value(s): ['7.9um']
#
# Parameter design_options.cplr_opts.coupling_length
# Number of unique values: 6
# Possible unique value(s): ['100um' '200um' '230um' '350um' '400um' '500um']
#
# Parameter design_options.cplr_opts.open_termination
# Number of unique values: 1
# Possible unique value(s): [False]
#
# Parameter design_options.cplr_opts.down_length
# Number of unique values: 1
# Possible unique value(s): ['50um']
#
# Parameter design_options.cplr_opts.orientation
# Number of unique values: 1
# Possible unique value(s): ['-90']
#
# Parameter coupler_type
# Number of unique values: 2
# Possible unique value(s): ['CLT' 'NCap']
#
# Parameter resonator_type
# Number of unique values: 2
# Possible unique value(s): ['half' 'quarter']
#
# Parameter design_tool
# Number of unique values: 2
# Possible unique value(s): ['Qiskit Metal' 'qiskit-metal']
#
# Parameter design_options.cpw_opts.lead.end_straight
# Number of unique values: 2
# Possible unique value(s): ['100um' '50um']
#
# Parameter design_options.cpw_opts.lead.start_jogged_extension.0
# Number of unique values: 6
# Possible unique value(s): ['0.0um' '133.33333333333334um' '153.33333333333334um'
#  '233.33333333333334um' '266.6666666666667um' 'R90']
#
# Parameter design_options.cplr_opts.cap_gap
# Number of unique values: 1
# Possible unique value(s): ['5um']
#
# Parameter design_options.cplr_opts.cap_width
# Number of unique values: 1
# Possible unique value(s): ['10um']
#
# Parameter design_options.cplr_opts.cap_gap_ground
# Number of unique values: 1
# Possible unique value(s): ['5.1um']
#
# Parameter design_options.cplr_opts.finger_length
# Number of unique values: 1
# Possible unique value(s): ['30um']
#
# Parameter design_options.cplr_opts.finger_count
# Number of unique values: 1
# Possible unique value(s): ['5']
#
# Parameter design_options.cplr_opts.cap_distance
# Number of unique values: 1
# Possible unique value(s): ['50.9um']

# %% [markdown]
# put the list below into ```y = y.drop(columns=columns_to_drop)```  in ml_00_data_analysis.ipynb. we need to drop other columns like  'design_tool' as well but those need to be added into the list manually.

# %%
single_valued_params
# Out:
# ['design_options.claw_opts.connection_pads.readout.connector_location',
#  'design_options.claw_opts.connection_pads.readout.connector_type',
#  'design_options.claw_opts.connection_pads.readout.ground_spacing',
#  'design_options.claw_opts.connection_pads.readout.claw_gap',
#  'design_options.claw_opts.connection_pads.readout.claw_width',
#  'design_options.claw_opts.connection_pads.readout.claw_cpw_width',
#  'design_options.claw_opts.connection_pads.readout.claw_cpw_length',
#  'design_options.claw_opts.orientation',
#  'design_options.claw_opts.pos_x',
#  'design_options.claw_opts.cross_length',
#  'design_options.claw_opts.cross_width',
#  'design_options.claw_opts.cross_gap',
#  'design_options.cpw_opts.fillet',
#  'design_options.cpw_opts.trace_width',
#  'design_options.cpw_opts.trace_gap',
#  'design_options.cpw_opts.lead.start_straight',
#  'design_options.cpw_opts.pin_inputs.start_pin.component',
#  'design_options.cpw_opts.pin_inputs.start_pin.pin',
#  'design_options.cpw_opts.pin_inputs.end_pin.component',
#  'design_options.cpw_opts.pin_inputs.end_pin.pin',
#  'design_options.cpw_opts.meander.spacing',
#  'design_options.cplr_opts.prime_width',
#  'design_options.cplr_opts.prime_gap',
#  'design_options.cplr_opts.second_width',
#  'design_options.cplr_opts.second_gap',
#  'design_options.cplr_opts.coupling_space',
#  'design_options.cplr_opts.open_termination',
#  'design_options.cplr_opts.down_length',
#  'design_options.cplr_opts.orientation',
#  'coupler_type',
#  'resonator_type',
#  'design_tool',
#  'design_options.cpw_opts.lead.end_straight',
#  'design_options.cplr_opts.cap_gap',
#  'design_options.cplr_opts.cap_width',
#  'design_options.cplr_opts.cap_gap_ground',
#  'design_options.cplr_opts.finger_length',
#  'design_options.cplr_opts.finger_count',
#  'design_options.cplr_opts.cap_distance']
